# %% [markdown]
# # CityBikes

# %% [markdown]
# ### Importing Packages

# %%
import requests
import os

# %%
import pandas as pd
import numpy as np
import json
import statsmodels.api as sm
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Exploring the structure of the API and understanding the data returned from querying the API
#
# To do this, first I will pull data from the citybikes API and store the JSON file in a variable and use that to check if the response works.

# %%
url_one = 'http://api.citybik.es/v2/networks'
bike_request = requests.get(url_one)
bike_request
# Out:
# <Response [200]>

# %%
bike_request_json = bike_request.json()

# %% [markdown]
# This JSON file is a list of nested dictionaires consisting of the companies responsible for bike rentals.

# %% [markdown]
# Send a request to CityBikes for the city of your choice.

# %% [markdown]
# Now, I will loop through the JSON file to isolate the bike comapny for running the CityBikes program in Bhopal

# %%
city_bike_companies = [] # create an empty list for city bike companies
for i in range(len(bike_request_json['networks'])): #a for loop to iterate through the json file
    if 'Gent' in bike_request_json['networks'][i]['location']['city']: #extracting the city for the company 
        city_bike_companies.append(bike_request_json['networks'][i])

city_bike_companies
# Out:
# [{'company': ['Donkey Republic'],
#   'gbfs_href': 'https://stables.donkey.bike/api/public/gbfs/donkey_gh/gbfs',
#   'href': '/v2/networks/donkey-gh',
#   'id': 'donkey-gh',
#   'location': {'city': 'Gent',
#    'country': 'BE',
#    'latitude': 51.05,
#    'longitude': 3.7303},
#   'name': 'Donkey Republic - Gent'}]

# %% [markdown]
# There is only one network company in Gent, Belgium that administers this city bikes program. Now, I will use the network ID I acquired from the request above to pull station data.

# %% [markdown]
# Q. Parse through the response to get the details you want for the bike stations in that city (latitude, longitude, number of bikes).

# %% [markdown]
# Now to pull station data for this specific company in Bhopal, I will create a new API request with this particular network ID I have acquired as the endpoint.
#
# The netword id for Gent is 'donkey-gh'

# %%
url_two = 'http://api.citybik.es/v2/networks/donkey-gh'
station_request = requests.get(url_two)
station_request
# Out:
# <Response [200]>

# %%
stations = station_request.json()

# %%
#To access the details, we parse the JSON file
stations['network']['stations']
# Out:
# [{'empty_slots': 2,
#   'extra': {'last_updated': 1713387373,
#    'renting': 1,
#    'returning': 1,
#    'uid': '23997'},
#   'free_bikes': 1,
#   'id': 'fedd9729d9183b05bb4a3bd9da7d7de1',
#   'latitude': 51.0602571,
#   'longitude': 3.7293461,
#   'name': 'Nieuwland 1',
#   'timestamp': '2024-04-18T00:29:30.343000Z'},
#  {'empty_slots': 9,
#   'extra': {'last_updated': 1713358694,
#    'renting': 1,
#    'returning': 1,
#    'uid': '23991'},
#   'free_bikes': 3,
#   'id': '360b8beb20716998aea9c9a9bbe9720f',
#   'latitude': 51.0236911,
#   'longitude': 3.6892353,
#   'name': 'IKEA',
#   'timestamp': '2024-04-18T00:29:30.349000Z'},
#  {'empty_slots': 2,
#   'extra': {'last_updated': 1713165557,
#    'renting': 1,
#    'returning': 1,
#    'uid': '12392'},
#   'free_bikes': 4,
#   'id': 'c41d2c76618e7fa70fb587d1c2f0497d',
#   'latitude': 51.0630685,
#   'longitude': 3.7159931,
#   'name': 'Opgeëistenlaan 401',
#   'timestamp': '2024-04-18T00:29:30.350000Z'},
#  {'empty_slots': 0,
#   'extra': {'last_updated': 1713297425,
#    'renting': 1,
#    'returning': 1,
#    'uid': '13169'},
#   'free_bikes': 3,
#   'id': '0af3043c5906684b3afc97f387c94430',
#   'latitude': 51.0585209,
#   'longitude': 3.7475825,
#   'name': 'Land van Waaslaan 128',
#   'timestamp': '2024-04-18T00:29:30.361000Z'},
#  {'empty_slots': 2,
#   'extra': {'last_updated': 1713385625,
#    'renting': 1,
#    'returning': 1,
#    'uid': '13245'},
#   'free_bikes': 1,
#   'id': '31578db5c5ecc8491f076cf2023ccc7d',
#   'latitude': 51.0565756,
#   'longitude': 3.7495297,
#   'name': 'Wittemolenstraat 40',
#   'timestamp': '2024-04-18T00:29:30.365000Z'},
#  {'empty_slots': 3,
#   'extra': {'last_updated': 1713376944,
#    'renting': 1,
#    'returning': 1,
#    'uid': '13162'},
#   'free_bikes': 0,
#   'id': 'dfb4810ce36bce22c088da09bc37132d',
#   'latitude': 51.0655317,
#   'longitude': 3.6993996,
#   'name': 'Groendreef 133',
#   'timestamp': '2024-04-18T00:29:30.368000Z'},
#  {'empty_slots': 0,
#   'extra': {'last_updated': 1713022327,
#    'renting': 1,
#    'returning': 1,
#    'uid': '13165'},
#   'free_bikes': 3,
#   'id': '1a3bb31080ba77d41404c93e0c0f0299',
#   'latitude': 51.0580561,
#   'longitude': 3.7422591,
#   'name': 'Kogelstraat 2',
#   'timestamp': '2024-04-18T00:29:30.565000Z'},
#  {'empty_slots': 0,
#   'extra': {'last_updated': 1712944927,
#    'renting': 1,
#    'returning': 1,
#    'uid': '16679'},
#   'free_bikes': 4,
#   'id': 'aaa26c27fc316b71372ceb012d8890d7',
#   'latitude': 51.0407663,
#   'longitude': 3.7615006,
#   'name': 'Emanuel Hielstraat 105',
#   'timestamp': '2024-04-18T00:29:30.372000Z'},
#  {'empty_slots': 2,
#   'extra': {'last_updated': 1713388297,
#    'renting': 1,
#    'returning': 1,
#    'uid': '18773'},
#   'free_bikes': 1,
#   'id': 'c88c6800155be87a311cdacd08762293',
#   'latitude': 51.0548977,
#   'longitude': 3.6992427,
#   'name': 'Rhino Boulder gym',
#   'timestamp': '2024-04-18T00:29:30.616000Z'},
#  {'empty_slots': 1,
#   'extra': {'last_updated': 1713328294,
#    'renting': 1,
#    'returning': 1,
#    'uid': '12068'},
#   'free_bikes': 1,
#   'id': '1b3506fe59b23039bab3dc8f524f625a',
#   'latitude': 51.0509493,
#   'longitude': 3.7320597,
#   'name': 'Belgradostraat 67',
#   'timestamp': '2024-04-18T00:29:30.380000Z'},
#  {'empty_slots': 3,
#   'extra': {'last_updated': 1713084810,
#    'renting': 1,
#    'returning': 1,
#    'uid': '12069'},
#   'free_bikes': 0,
#   'id': '1fcaa8749188138a506a8e3aa212814e',
#   'latitude': 51.049469,
#   'longitude': 3.7396381,
#   'name': 'Kasteellaan 54',
#   'timestamp': '2024-04-18T00:29:30.380000Z'},
#  {'empty_slots': 12,
#   'extra': {'last_updated': 1713378451,
#    'renting': 1,
#    'returning': 1,
#    'uid': '12061'},
#   'free_bikes': 0,
#   'id': '410f1baccd30d330aca8009211c62fbe',
#   'latitude': 51.0503505,
#   'longitude': 3.7104104,
#   'name': 'Coupure Links 501',
#   'timestamp': '2024-04-18T00:29:30.381000Z'},
#  {'empty_slots': 3,
#   'extra': {'last_updated': 1713399382,
#    'renting': 1,
#    'returning': 1,
#    'uid': '19787'},
#   'free_bikes': 3,
#   'id': 'acab2936b4d32b1cd7d5cda63597f0b0',
#   'latitude': 51.0438426,
#   'longitude': 3.7215985,
#   'name': 'Kortrijksepoortstraat',
#   'timestamp': '2024-04-18T00:29:30.382000Z'},
#  {'empty_slots': 2,
#   'extra': {'address': ', ',
#    'last_updated': 1713377642,
#    'post_code': '',
#    'renting': 1,
#    'returning': 1,
#    'uid': '12067'},
#   'free_bikes': 1,
#   'id': '0546d825dfb50724ced5555d608abe99',
#   'latitude': 51.0618368,
#   'longitude': 3.7243753,
#   'name': 'Fratersplein 1',
#   'timestamp': '2024-04-18T00:29:30.383000Z'},
#  {'empty_slots': 3,
#   'extra': {'address': ', ',
#    'last_updated': 1713346888,
#    'post_code': '',
#    'renting': 1,
#    'returning': 1,
#    'uid': '12150'},
#   'free_bikes': 0,
#   'id': 'a1548171597de0c03c922c566938fa76',
#   'latitude': 51.0376269,
#   'longitude': 3.7147088,
#   'name': 'Koningin Elisabethlaan 18',
#   'timestamp': '2024-04-18T00:29:31.272000Z'},
#  {'empty_slots': 5,
#   'extra': {'last_updated': 1713347660,
#    'renting': 1,
#    'returning': 1,
#    'uid': '20360'},
#   'free_bikes': 0,
#   'id': '6d9592273f520fc85d1201f1f153e850',
#   'latitude': 51.0351449,
#   'longitude': 3.7044468,
#   'name': 'HoGent Sporthal',
#   'timestamp': '2024-04-18T00:29:30.388000Z'},
#  {'empty_slots': 5,
#   'extra': {'last_updated': 1713368794,
#    'renting': 1,
#    'returning': 1,
#    'uid': '20361'},
#   'free_bikes': 1,
#   'id': '2e6f52f47d12de5f800f3ec732114ecd',
#   'latitude': 51.0343421,
#   'longitude': 3.7042949,
#   'name': 'XIOR Student Housing ',
#   'timestamp': '2024-04-18T00:29:30.389000Z'},
#  {'empty_slots': 2,
#   'extra': {'last_updated': 1713382748,
#    'renting': 1,
#    'returning': 1,
#    'uid': '12151'},
#   'free_bikes': 1,
#   'id': 'c3f3cb05411a0e86ec58d50fe9f01be8',
#   'latitude': 51.0344795,
#   'longitude': 3.717256,
#   'name': 'Parklaan 98',
#   'timestamp': '2024-04-18T00:29:31.274000Z'},
#  {'empty_slots': 2,
#   'extra': {'last_updated': 1713276550,
#    'renting': 1,
#    'returning': 1,
#    'uid': '21848'},
#   'free_bikes': 0,
#   'id': '01b098a044c60e31c642865cf0ce1b3e',
#   'latitude': 51.0525839,
#   'longitude': 3.7088423,
#   'name': 'Ekkergemstraat 9',
#   'timestamp': '2024-04-18T00:29:30.390000Z'},
#  {'empty_slots': 3,
#   'extra': {'last_updated': 1712992810,
#    'renting': 1,
#    'returning': 1,
#    'uid': '21847'},
#   'free_bikes': 0,
#   'id': '30659032c2a35a4d7311a0e1933d4e89',
#   'latitude': 51.0587496,
#   'longitude': 3.713344,
#   'name': 'Hector van Wittenberghe',
#   'timestamp': '2024-04-18T00:29:30.392000Z'},
#  {'empty_slots': 11,
#   'extra': {'last_updated': 1713389488,
#    'renting': 1,
#    'returning': 1,
#    'uid': '17222'},
#   'free_bikes': 1,
#   'id': '0f5d523e22bc6d0a8cadcdfcb2d66105',
#   'latitude': 51.053617,
#   'longitude': 3.7403016,
#   'name': 'Flixbus Ghent',
#   'timestamp': '2024-04-18T00:29:30.393000Z'},
#  {'empty_slots': 3,
#   'extra': {'last_updated': 1713123335,
#    'renting': 1,
#    'returning': 1,
#    'uid': '16708'},
#   'free_bikes': 0,
#   'id': '9fb7767ba19d7e665b92c41d329a37de',
#   'latitude': 51.0444101,
#   'longitude': 3.7340243,
#   'name': 'Vijfwindgatenstraat 23',
#   'timestamp': '2024-04-18T00:29:30.398000Z'},
#  {'empty_slots': 3,
#   'extra': {'last_updated': 1713178708,
#    'renting': 1,
#    'returning': 1,
#    'uid': '16705'},
#   'free_bikes': 0,
#   'id': '11b81031b4ea4395876c7a7dbf4f14da',
#   'latitude': 51.0419186,
#   'longitude': 3.7316075,
#   'name': 'François Benardstraat 80',
#   'timestamp': '2024-04-18T00:29:30.408000Z'},
#  {'empty_slots': 6,
#   'extra': {'last_updated': 1713215592,
#    'renting': 1,
#    'returning': 1,
#    'uid': '16706'},
#   'free_bikes': 0,
#   'id': '2caa169946b51c132094aa06e634fcad',
#   'latitude': 51.0392616,
#   'longitude': 3.7364216,
#   'name': 'Hubert Frère-Orbanlaan 634',
#   'timestamp': '2024-04-18T00:29:30.412000Z'},
#  {'empty_slots': 2,
#   'extra': {'last_updated': 1713281354,
#    'renting': 1,
#    'returning': 1,
#    'uid': '16700'},
#   'free_bikes': 1,
#   'id': 'cd7001bfe1befebc9058bdc98b2c8086',
#   'latitude': 51.0406669,
#   'longitude': 3.7272728,
#   'name': 'Voetweg 19',
#   'timestamp': '2024-04-18T00:29:30.413000Z'},
#  {'empty_slots': 6,
#   'extra': {'last_updated': 1713189621,
#    'renting': 1,
#    'returning': 1,
#    'uid': '14695'},
#   'free_bikes': 0,
#   'id': 'bb7ae494088165917b10648d1891f7f8',
#   'latitude': 51.0523184,
#   'longitude': 3.7257917,
#   'name': 'Lange Kruisstraat 31',
#   'timestamp': '2024-04-18T00:29:30.418000Z'},
#  {'empty_slots': 16,
#   'extra': {'last_updated': 1713170707,
#    'renting': 1,
#    'returning': 1,
#    'uid': '12015'},
#   'free_bikes': 0,
#   'id': 'fecd51be0c13ce728017a0127aae2152',
#   'latitude': 51.0526166,
#   'longitude': 3.7288539,
#   'name': 'Bisdomplein GF',
#   'timestamp': '2024-04-18T00:29:30.419000Z'},
#  {'empty_slots': 2,
#   'extra': {'last_updated': 1713391992,
#    'renting': 1,
#    'returning': 1,
#    'uid': '12014'},
#   'free_bikes': 2,
#   'id': '1c9dc37c9f4ad22a9af38194caccf874',
#   'latitude': 51.0552908,
#   'longitude': 3.7164211,
#   'name': 'Brouwerstraat 1',
#   'timestamp': '2024-04-18T00:29:30.420000Z'},
#  {'empty_slots': 10,
#   'extra': {'last_updated': 1713094037,
#    'renting': 1,
#    'returning': 1,
#    'uid': '12016'},
#   'free_bikes': 0,
#   'id': '637df9d7130f3194044e9e1891c240e9',
#   'latitude': 51.0535559,
#   'longitude': 3.7308213,
#   'name': 'Reep',
#   'timestamp': '2024-04-18T00:29:30.428000Z'},
#  {'empty_slots': 12,
#   'extra': {'last_updated': 1713360992,
#    'renting': 1,
#    'returning': 1,
#    'uid': '12011'},
#   'free_bikes': 0,
#   'id': '8ecf121c3ab53bb2d5a27f279c82d112',
#   'latitude': 51.0521669,
#   'longitude': 3.7174294,
#   'name': 'Alexianenplein 1',
#   'timestamp': '2024-04-18T00:29:30.429000Z'},
#  {'empty_slots': 5,
#   'extra': {'last_updated': 1713375137,
#    'renting': 1,
#    'returning': 1,
#    'uid': '12084'},
#   'free_bikes': 1,
#   'id': '8382d32e7725c746e331dfac37e28800',
#   'latitude': 51.0392373,
#   'longitude': 3.7295442,
#   'name': 'Ter Platen 32',
#   'timestamp': '2024-04-18T00:29:30.443000Z'},
#  {'empty_slots': 1,
#   'extra': {'last_updated': 1713367332,
#    'renting': 1,
#    'returning': 1,
#    'uid': '12082'},
#   'free_bikes': 1,
#   'id': 'ad2be11652d6624b4d4c2fbd413bf528',
#   'latitude': 51.0635508,
#   'longitude': 3.7256125,
#   'name': 'Tolhuislaan 77',
#   'timestamp': '2024-04-18T00:29:30.444000Z'},
#  {'empty_slots': 3,
#   'extra': {'last_updated': 1713355391,
#    'renting': 1,
#    'returning': 1,
#    'uid': '12083'},
#   'free_bikes': 1,
#   'id': '78e75ce0a100d0137b9e3025077cae83',
#   'latitude': 51.0486187,
#   'longitude': 3.7234384,
#   'name': 'Savaanstraat 78',
#   'timestamp': '2024-04-18T00:29:30.448000Z'},
#  {'empty_slots': 8,
#   'extra': {'last_updated': 1713378295,
#    'renting': 1,
#    'returning': 1,
#    'uid': '12080'},
#   'free_bikes': 0,
#   'id': 'c3c97d972307186c9f2301d3fe97517e',
#   'latitude': 51.0610287,
#   'longitude': 3.7340166,
#   'name': 'Ham 155',
#   'timestamp': '2024-04-18T00:29:30.452000Z'},
#  {'empty_slots': 3,
#   'extra': {'last_updated': 1713281616,
#    'renting': 1,
#    'returning': 1,
#    'uid': '12081'},
#   'free_bikes': 1,
#   'id': '1b8034523fc4ba1cb205dd612e37496f',
#   'latitude': 51.0596372,
#   'longitude': 3.7323693,
#   'name': 'Blekerijstraat 50',
#   'timestamp': '2024-04-18T00:29:30.454000Z'},
#  {'empty_slots': 3,
#   'extra': {'last_updated': 1713245923,
#    'renting': 1,
#    'returning': 1,
#    'uid': '12121'},
#   'free_bikes': 0,
#   'id': '86933ae58845264c4df1d2380867bd48',
#   'latitude': 51.0529963,
#   'longitude': 3.7167423,
#   'name': 'Oude Houtlei 44',
#   'timestamp': '2024-04-18T00:29:31.154000Z'},
#  {'empty_slots': 6,
#   'extra': {'last_updated': 1713384672,
#    'renting': 1,
#    'returning': 1,
#    'uid': '23145'},
#   'free_bikes': 0,
#   'id': '48c3a40d383d13e41cf4d4f193d3b7fb',
#   'latitude': 51.05695,
#   'longitude': 3.7074666,
#   'name': 'Hembysebolwerk',
#   'timestamp': '2024-04-18T00:29:31.161000Z'},
#  {'empty_slots': 2,
#   'extra': {'address': ', ',
#    'last_updated': 1713375002,
#    'post_code': '',
#    'renting': 1,
#    'returning': 1,
#    'uid': '12124'},
#   'free_bikes': 4,
#   'id': 'f7a6ee23fc0e844d63fd15d9b4175b92',
#   'latitude': 51.0588285,
#   'longitude': 3.7267639,
#   'name': 'Ottogracht 55',
#   'timestamp': '2024-04-18T00:29:30.479000Z'},
#  {'empty_slots': 3,
#   'extra': {'last_updated': 1713399467,
#    'renting': 1,
#    'returning': 1,
#    'uid': '12088'},
#   'free_bikes': 0,
#   'id': '1ea7b39786ac4c6dc9d96572f92ce385',
#   'latitude': 51.0374543,
#   'longitude': 3.7412398,
#   'name': 'Ledebergplein 39',
#   'timestamp': '2024-04-18T00:29:30.480000Z'},
#  {'empty_slots': 1,
#   'extra': {'last_updated': 1713373869,
#    'renting': 1,
#    'returning': 1,
#    'uid': '23893'},
#   'free_bikes': 2,
#   'id': 'b06e8b3b970597d134c8e46daa306347',
#   'latitude': 51.0482402,
#   'longitude': 3.7025284,
#   'name': 'Artevelde Hogeschool Watersportbaan',
#   'timestamp': '2024-04-18T00:29:30.494000Z'},
#  {'empty_slots': 3,
#   'extra': {'last_updated': 1713358061,
#    'renting': 1,
#    'returning': 1,
#    'uid': '21323'},
#   'free_bikes': 0,
#   'id': '63fd9646ea2067a76d5c3bbe85c60f0d',
#   'latitude': 51.0740496,
#   'longitude': 3.7284415,
#   'name': 'Kopenhagenstraat',
#   'timestamp': '2024-04-18T00:29:31.337000Z'},
#  {'empty_slots': 6,
#   'extra': {'last_updated': 1713361430,
#    'renting': 1,
#    'returning': 1,
#    'uid': '22540'},
#   'free_bikes': 0,
#   'id': 'b559c95a78c11f8c88120736ee3137cc',
#   'latitude': 51.0521984,
#   'longitude': 3.7239713,
#   'name': 'Campus Aula',
#   'timestamp': '2024-04-18T00:29:30.503000Z'},
#  {'empty_slots': 3,
#   'extra': {'last_updated': 1713377424,
#    'renting': 1,
#    'returning': 1,
#    'uid': '18457'},
#   'free_bikes': 0,
#   'id': 'afb911a0285187077bab05003f8e038e',
#   'latitude': 51.0780114,
#   'longitude': 3.7300475,
#   'name': 'Dukkeldamstraat',
#   'timestamp': '2024-04-18T00:29:31.220000Z'},
#  {'empty_slots': 2,
#   'extra': {'last_updated': 1713198109,
#    'renting': 1,
#    'returning': 1,
#    'uid': '18456'},
#   'free_bikes': 1,
#   'id': '36dda7b4926cb240dfa3a353945da2dd',
#   'latitude': 51.0731978,
#   'longitude': 3.731295,
#   'name': 'Kajuitstraat',
#   'timestamp': '2024-04-18T00:29:31.224000Z'},
#  {'empty_slots': 13,
#   'extra': {'address': ', ',
#    'last_updated': 1713394587,
#    'post_code': '',
#    'renting': 1,
#    'returning': 1,
#    'uid': '21444'},
#   'free_bikes': 9,
#   'id': 'd3ab81397ef1bc938d319bd75ea680c8',
#   'latitude': 51.0370561,
#   'longitude': 3.7102414,
#   'name': '2de Gent-Sint-Pietersstation Noord',
#   'timestamp': '2024-04-18T00:29:30.520000Z'},
#  {'empty_slots': 12,
#   'extra': {'last_updated': 1712966645,
#    'renting': 1,
#    'returning': 1,
#    'uid': '21333'},
#   'free_bikes': 0,
#   'id': '5fa5584d4d8f8dce2071b928989eb476',
#   'latitude': 51.0522008,
#   'longitude': 3.7222339,
#   'name': 'Volderstraat b&b hotel',
#   'timestamp': '2024-04-18T00:29:30.526000Z'},
#  {'empty_slots': 2,
#   'extra': {'last_updated': 1713199328,
#    'renting': 1,
#    'returning': 1,
#    'uid': '21330'},
#   'free_bikes': 1,
#   'id': '8d13d393ace4f1e7585cf637e2046c9b',
#   'latitude': 51.0479245,
#   'longitude': 3.7475342,
#   'name': 'Emile Moysonlaan',
#   'timestamp': '2024-04-18T00:29:30.528000Z'},
#  {'empty_slots': 6,
#   'extra': {'last_updated': 1713335033,
#    'renting': 1,
#    'returning': 1,
#    'uid': '13207'},
#   'free_bikes': 0,
#   'id': 'b6ae4c0c1a89e82a6f20af66612af829',
#   'latitude': 51.0404691,
#   'longitude': 3.7429901,
#   'name': 'Brusselsesteenweg 316',
#   'timestamp': '2024-04-18T00:29:30.529000Z'},
#  {'empty_slots': 2,
#   'extra': {'last_updated': 1713361923,
#    'renting': 1,
#    'returning': 1,
#    'uid': '13201'},
#   'free_bikes': 1,
#   'id': 'ec41199bd91f06bd9c22c898898e2500',
#   'latitude': 51.0337461,
#   'longitude': 3.7449185,
#   'name': 'Moriaanstraat 70',
#   'timestamp': '2024-04-18T00:29:31.284000Z'},
#  {'empty_slots': 6,
#   'extra': {'last_updated': 1713025451,
#    'renting': 1,
#    'returning': 1,
#    'uid': '22539'},
#   'free_bikes': 0,
#   'id': '6e24e28ee6a13e80fd699b5274b459e8',
#   'latitude': 51.052252,
#   'longitude': 3.7232608,
#   'name': 'Pannenkoekenhuis',
#   'timestamp': '2024-04-18T00:29:30.548000Z'},
#  {'empty_slots': 3,
#   'extra': {'last_updated': 1713400090,
#    'renting': 1,
#    'returning': 1,
#    'uid': '12198'},
#   'free_bikes': 1,
#   'id': 'c79ad33e91a47217daba30120955cd8a',
#   'latitude': 51.0490388,
#   'longitude': 3.7142959,
#   'name': 'Lieven de Winnestraat 54',
#   'timestamp': '2024-04-18T00:29:30.577000Z'},
#  {'empty_slots': 2,
#   'extra': {'last_updated': 1713372682,
#    'renting': 1,
#    'returning': 1,
#    'uid': '21538'},
#   'free_bikes': 2,
#   'id': 'c78b3fa77fafe6a072047b34c934b394',
#   'latitude': 51.06047,
#   'longitude': 3.698906,
#   'name': 'Acaciapark',
#   'timestamp': '2024-04-18T00:29:30.553000Z'},
#  {'empty_slots': 3,
#   'extra': {'last_updated': 1712905358,
#    'renting': 1,
#    'returning': 1,
#    'uid': '21537'},
#   'free_bikes': 0,
#   'id': 'e96dc4d40ec649747b84ad88ce7452ac',
#   'latitude': 51.0595685,
#   'longitude': 3.6985802,
#   'name': 'Sparrestraat 23',
#   'timestamp': '2024-04-18T00:29:30.557000Z'},
#  {'empty_slots': 1,
#   'extra': {'last_updated': 1713372013,
#    'renting': 1,
#    'returning': 1,
#    'uid': '17067'},
#   'free_bikes': 2,
#   'id': '06238d9c770ffff83eb825f2750b8c28',
#   'latitude': 51.0760789,
#   'longitude': 3.7304208,
#   'name': 'Meulesteedsesteenweg 146A',
#   'timestamp': '2024-04-18T00:29:31.135000Z'},
#  {'empty_slots': 1,
#   'extra': {'last_updated': 1713375995,
#    'renting': 1,
#    'returning': 1,
#    'uid': '13181'},
#   'free_bikes': 1,
#   'id': '15c1fe1e6905d3c2c75149c7fd8e9b1f',
#   'latitude': 51.0673695,
#   'longitude': 3.7227782,
#   'name': 'Gasmeterlaan 191',
#   'timestamp': '2024-04-18T00:29:31.136000Z'},
#  {'empty_slots': 6,
#   'extra': {'address': ', ',
#    'last_updated': 1713338653,
#    'post_code': '',
#    'renting': 1,
#    'returning': 1,
#    'uid': '16628'},
#   'free_bikes': 0,
#   'id': 'ca54282b0972fa7c46c9e0f7f1a0d8d1',
#   'latitude': 51.0684514,
#   'longitude': 3.691455,
#   'name': 'Linnenstraat 127',
#   'timestamp': '2024-04-18T00:29:30.568000Z'},
#  {'empty_slots': 6,
#   'extra': {'last_updated': 1712934235,
#    'renting': 1,
#    'returning': 1,
#    'uid': '12050'},
#   'free_bikes': 0,
#   'id': 'd03c28fb2a0b6f1c59f713b00e78b298',
#   'latitude': 51.0382829,
#   'longitude': 3.7231035,
#   'name': 'SMAK - Stedelijk Museum voor Actuele Kunst',
#   'timestamp': '2024-04-18T00:29:30.581000Z'},
#  {'empty_slots': 12,
#   'extra': {'last_updated': 1713395483,
#    'renting': 1,
#    'returning': 1,
#    'uid': '12053'},
#   'free_bikes': 3,
#   'id': '739ceb4a3c815948b1a197efffb66085',
#   'latitude': 51.0407704,
#   'longitude': 3.7256633,
#   'name': 'Dronkey 2',
#   'timestamp': '2024-04-18T00:29:30.582000Z'},
#  {'empty_slots': 10,
#   'extra': {'last_updated': 1713376358,
#    'renting': 1,
#    'returning': 1,
#    'uid': '12052'},
#   'free_bikes': 2,
#   'id': '039374c72295ea6698c3626d478b85d0',
#   'latitude': 51.0417154,
#   'longitude': 3.7293423,
#   'name': 'Muinkkaai 119',
#   'timestamp': '2024-04-18T00:29:30.584000Z'},
#  {'empty_slots': 3,
#   'extra': {'last_updated': 1713332250,
#    'renting': 1,
#    'returning': 1,
#    'uid': '12054'},
#   'free_bikes': 0,
#   'id': '7d770c78d187f3e02796b4e835f76809',
#   'latitude': 51.0441471,
#   'longitude': 3.7230422,
#   'name': 'Karel van Hulthemstraat 36',
#   'timestamp': '2024-04-18T00:29:30.585000Z'},
#  {'empty_slots': 24,
#   'extra': {'last_updated': 1713283635,
#    'renting': 1,
#    'returning': 1,
#    'uid': '12057'},
#   'free_bikes': 0,
#   'id': '5ae9e5c04488fb16dd5963b238664aa5',
#   'latitude': 51.0433045,
#   'longitude': 3.7177672,
#   'name': 'STAM - Stadsmuseum Gent',
#   'timestamp': '2024-04-18T00:29:30.590000Z'},
#  {'empty_slots': 12,
#   'extra': {'last_updated': 1713129083,
#    'renting': 1,
#    'returning': 1,
#    'uid': '12056'},
#   'free_bikes': 0,
#   'id': '15e9bcc8527d8e07220ea3e49bb774f3',
#   'latitude': 51.0466084,
#   'longitude': 3.7194902,
#   'name': 'Coupure Links 15',
#   'timestamp': '2024-04-18T00:29:30.591000Z'},
#  {'empty_slots': 6,
#   'extra': {'last_updated': 1713199706,
#    'renting': 1,
#    'returning': 1,
#    'uid': '16626'},
#   'free_bikes': 0,
#   'id': 'a5ccef3ac4c6523f8f7e124f2dbecccb',
#   'latitude': 51.0172252,
#   'longitude': 3.7196675,
#   'name': 'Gestichtstraat 3',
#   'timestamp': '2024-04-18T00:29:30.594000Z'},
#  {'empty_slots': 9,
#   'extra': {'last_updated': 1713388644,
#    'renting': 1,
#    'returning': 1,
#    'uid': '12058'},
#   'free_bikes': 3,
#   'id': '9ec306e6d7a56100f1a2a0770bcb1455',
#   'latitude': 51.045314,
#   'longitude': 3.7145362,
#   'name': 'KASKCinema',
#   'timestamp': '2024-04-18T00:29:30.598000Z'},
#  {'empty_slots': 2,
#   'extra': {'last_updated': 1713332989,
#    'renting': 1,
#    'returning': 1,
#    'uid': '12192'},
#   'free_bikes': 1,
#   'id': 'd9f901dfc763a6005c3a197242af2f83',
#   'latitude': 51.0642773,
#   'longitude': 3.6979297,
#   'name': 'Kiekenstraat 8',
#   'timestamp': '2024-04-18T00:29:30.604000Z'},
#  {'empty_slots': 2,
#   'extra': {'last_updated': 1713372821,
#    'renting': 1,
#    'returning': 1,
#    'uid': '12194'},
#   'free_bikes': 2,
#   'id': 'd8a61f7ed7a6fabd1b57d8af0030c2f6',
#   'latitude': 51.0499168,
#   'longitude': 3.7173279,
#   'name': 'Iepenstraat 2',
#   'timestamp': '2024-04-18T00:29:30.605000Z'},
#  {'empty_slots': 1,
#   'extra': {'last_updated': 1713396119,
#    'renting': 1,
#    'returning': 1,
#    'uid': '16588'},
#   'free_bikes': 2,
#   'id': 'a20efc6130c6b5a9f7a227c73d427106',
#   'latitude': 51.0685655,
#   'longitude': 3.6850426,
#   'name': 'Brugsesteenweg 370',
#   'timestamp': '2024-04-18T00:29:30.608000Z'},
#  {'empty_slots': 0,
#   'extra': {'last_updated': 1712842302,
#    'renting': 1,
#    'returning': 1,
#    'uid': '24255'},
#   'free_bikes': 3,
#   'id': '1f7e478c3787e14b5f4ca1f1f831a3c1',
#   'latitude': 51.0811966,
#   'longitude': 3.7048535,
#   'name': 'Roodborstjesstraat',
#   'timestamp': '2024-04-18T00:29:30.975000Z'},
#  {'empty_slots': 12,
#   'extra': {'last_updated': 1713375728,
#    'renting': 1,
#    'returning': 1,
#    'uid': '12196'},
#   'free_bikes': 0,
#   'id': 'f022ca854bd64064a98753391f68b1b6',
#   'latitude': 51.0545287,
#   'longitude': 3.7173127,
#   'name': 'Poel 15',
#   'timestamp': '2024-04-18T00:29:30.607000Z'},
#  {'empty_slots': 2,
#   'extra': {'last_updated': 1713338656,
#    'renting': 1,
#    'returning': 1,
#    'uid': '16678'},
#   'free_bikes': 0,
#   'id': '37d89cc58470d6b3c7bd6f4644fce078',
#   'latitude': 51.0369233,
#   'longitude': 3.7444712,
#   'name': 'Van Den Heckestraat 7',
#   'timestamp': '2024-04-18T00:29:30.378000Z'},
#  {'empty_slots': 3,
#   'extra': {'last_updated': 1713379194,
#    'renting': 1,
#    'returning': 1,
#    'uid': '16449'},
#   'free_bikes': 0,
#   'id': '0728885bea6c3898896362822e7f1591',
#   'latitude': 51.0513956,
#   'longitude': 3.7059044,
#   'name': 'Ekkergemstraat 34',
#   'timestamp': '2024-04-18T00:29:30.619000Z'},
#  {'empty_slots': 11,
#   'extra': {'last_updated': 1713339260,
#    'renting': 1,
#    'returning': 1,
#    'uid': '15560'},
#   'free_bikes': 1,
#   'id': '14cb0473ca0b8a57edbdc25ae6679710',
#   'latitude': 51.0265572,
#   'longitude': 3.7141567,
#   'name': 'Sterre Hoofdingang',
#   'timestamp': '2024-04-18T00:29:30.621000Z'},
#  {'empty_slots': 3,
#   'extra': {'last_updated': 1713355056,
#    'renting': 1,
#    'returning': 1,
#    'uid': '16692'},
#   'free_bikes': 0,
#   'id': '6e81b69e9b5f71458f07d4ce5fa18fe0',
#   'latitude': 51.059432,
#   'longitude': 3.7123166,
#   'name': 'Hector van Wittenberghestraat 55',
#   'timestamp': '2024-04-18T00:29:30.629000Z'},
#  {'empty_slots': 3,
#   'extra': {'last_updated': 1713248366,
#    'renting': 1,
#    'returning': 1,
#    'uid': '16690'},
#   'free_bikes': 0,
#   'id': '15c2c27d8a652ded0b756607b4577153',
#   'latitude': 51.0506871,
#   'longitude': 3.7130943,
#   'name': 'Papegaaistraat 59',
#   'timestamp': '2024-04-18T00:29:30.633000Z'},
#  {'empty_slots': 14,
#   'extra': {'last_updated': 1713390917,
#    'renting': 1,
#    'returning': 1,
#    'uid': '16699'},
#   'free_bikes': 2,
#   'id': 'ef142705ab7da9b328648e0f8e41fd8f',
#   'latitude': 51.0396756,
#   'longitude': 3.7288916,
#   'name': 'UGent Homes',
#   'timestamp': '2024-04-18T00:29:30.637000Z'},
#  {'empty_slots': 6,
#   'extra': {'last_updated': 1713376324,
#    'renting': 1,
#    'returning': 1,
#    'uid': '16698'},
#   'free_bikes': 6,
#   'id': '7ea5cae4a25e429c7c341cb0e3dd2caf',
#   'latitude': 51.050446,
#   'longitude': 3.7247839,
#   'name': 'Kouter 175',
#   'timestamp': '2024-04-18T00:29:30.638000Z'},
#  {'empty_slots': 2,
#   'extra': {'last_updated': 1713358239,
#    'renting': 1,
#    'returning': 1,
#    'uid': '24241'},
#   'free_bikes': 1,
#   'id': '67cf5356223b4cdd7d63037b97913d1b',
#   'latitude': 51.0590604,
#   'longitude': 3.7075347,
#   'name': 'Guldenvliesstraat 2-32',
#   'timestamp': '2024-04-18T00:29:30.640000Z'},
#  {'empty_slots': 3,
#   'extra': {'last_updated': 1713333756,
#    'renting': 1,
#    'returning': 1,
#    'uid': '12373'},
#   'free_bikes': 0,
#   'id': 'daadc17d513fa4b17d65cc57eee230dc',
#   'latitude': 51.0487779,
#   'longitude': 3.7430119,
#   'name': 'Forelstraat 109',
#   'timestamp': '2024-04-18T00:29:30.657000Z'},
#  {'empty_slots': 9,
#   'extra': {'last_updated': 1713389939,
#    'renting': 1,
#    'returning': 1,
#    'uid': '17180'},
#   'free_bikes': 11,
#   'id': 'a90475191431fa0504055cd3f9624f50',
#   'latitude': 51.0360093,
#   'longitude': 3.7119168,
#   'name': 'Gent-Sint-Pietersstation Noord',
#   'timestamp': '2024-04-18T00:29:30.653000Z'},
#  {'empty_slots': 3,
#   'extra': {'last_updated': 1713378506,
#    'renting': 1,
#    'returning': 1,
#    'uid': '17268'},
#   'free_bikes': 1,
#   'id': 'fa5ba459c6586ffe4fb656b209d50ae2',
#   'latitude': 51.0538571,
#   'longitude': 3.7016084,
#   'name': 'Johannes Schrantstraat',
#   'timestamp': '2024-04-18T00:29:30.655000Z'},
#  {'empty_slots': 1,
#   'extra': {'last_updated': 1713276113,
#    'renting': 1,
#    'returning': 1,
#    'uid': '12063'},
#   'free_bikes': 2,
#   'id': '2b94135a7fddb4b8c6366f96b72b52be',
#   'latitude': 51.0572295,
#   'longitude': 3.7172372,
#   'name': 'Abrahamstraat',
#   'timestamp': '2024-04-18T00:29:30.537000Z'},
#  {'empty_slots': 1,
#   'extra': {'last_updated': 1713364172,
#    'renting': 1,
#    'returning': 1,
#    'uid': '12377'},
#   'free_bikes': 2,
#   'id': 'c4c341211dc9fccf3f8c01a8c633fa8f',
#   'latitude': 51.0639684,
#   'longitude': 3.7295391,
#   'name': 'Doornzelestraat 1',
#   'timestamp': '2024-04-18T00:29:30.658000Z'},
#  {'empty_slots': 6,
#   'extra': {'last_updated': 1713332448,
#    'renting': 1,
#    'returning': 1,
#    'uid': '12400'},
#   'free_bikes': 0,
#   'id': 'c14836fa30d12c4568d4603741542537',
#   'latitude': 51.0620088,
#   'longitude': 3.7031366,
#   'name': 'Groendreef 47',
#   'timestamp': '2024-04-18T00:29:30.661000Z'},
#  {'empty_slots': 6,
#   'extra': {'address': ', ',
#    'last_updated': 1712785967,
#    'post_code': '',
#    'renting': 1,
#    'returning': 1,
#    'uid': '16967'},
#   'free_bikes': 0,
#   'id': 'ee4b3a34e33c19ca79aad9878e2ea308',
#   'latitude': 51.0678339,
#   'longitude': 3.7281344,
#   'name': 'Bar Oswald',
#   'timestamp': '2024-04-18T00:29:30.664000Z'},
#  {'empty_slots': 2,
#   'extra': {'last_updated': 1713379758,
#    'renting': 1,
#    'returning': 1,
#    'uid': '12177'},
#   'free_bikes': 2,
#   'id': 'fb0646bb18bbeb5dd4c1af0af9e498fe',
#   'latitude': 51.0390628,
#   'longitude': 3.7087229,
#   'name': 'Patijntjestraat 11',
#   'timestamp': '2024-04-18T00:29:30.667000Z'},
#  {'empty_slots': 2,
#   'extra': {'last_updated': 1713331526,
#    'renting': 1,
#    'returning': 1,
#    'uid': '21263'},
#   'free_bikes': 1,
#   'id': 'aac91dcfebcf4143913803e1df988857',
#   'latitude': 51.0632119,
#   'longitude': 3.7000761,
#   'name': 'Lobeliastraat',
#   'timestamp': '2024-04-18T00:29:30.672000Z'},
#  {'empty_slots': 0,
#   'extra': {'last_updated': 1713399409,
#    'renting': 1,
#    'returning': 1,
#    'uid': '12388'},
#   'free_bikes': 1,
#   'id': '56c4f1d888b9261c4a9b3d19cbf3598e',
#   'latitude': 51.0648525,
#   'longitude': 3.7266142,
#   'name': 'Tolhuislaan 148',
#   'timestamp': '2024-04-18T00:29:31.364000Z'},
#  {'empty_slots': 3,
#   'extra': {'last_updated': 1713293577,
#    'renting': 1,
#    'returning': 1,
#    'uid': '21776'},
#   'free_bikes': 0,
#   'id': '6aa5f68930b1c3216094398700ab6c57',
#   'latitude': 51.060323,
#   'longitude': 3.6892785,
#   'name': 'Charlotte Despardstraat 30',
#   'timestamp': '2024-04-18T00:29:30.681000Z'},
#  {'empty_slots': 3,
#   'extra': {'last_updated': 1713390018,
#    'renting': 1,
#    'returning': 1,
#    'uid': '21775'},
#   'free_bikes': 0,
#   'id': 'df90f60cecf08c820f62a73ceb7ce8ea',
#   'latitude': 51.0601682,
#   'longitude': 3.6903478,
#   'name': 'Gatti De Gammondstraat 15',
#   'timestamp': '2024-04-18T00:29:30.688000Z'},
#  {'empty_slots': 3,
#   'extra': {'last_updated': 1713312467,
#    'renting': 1,
#    'returning': 1,
#    'uid': '18800'},
#   'free_bikes': 0,
#   'id': 'abeef1501296f809e1d4627dfbd34e66',
#   'latitude': 51.0464312,
#   'longitude': 3.732826,
#   'name': 'Hubert Frere Orbanlaan',
#   'timestamp': '2024-04-18T00:29:30.691000Z'},
#  {'empty_slots': 6,
#   'extra': {'last_updated': 1713210092,
#    'renting': 1,
#    'returning': 1,
#    'uid': '19383'},
#   'free_bikes': 0,
#   'id': '4c4db03e2ac6eb77f5da4ca584da33a0',
#   'latitude': 51.0604647,
#   'longitude': 3.7107695,
#   'name': 'Filips van Cleeflaan',
#   'timestamp': '2024-04-18T00:29:30.698000Z'},
#  {'empty_slots': 4,
#   'extra': {'last_updated': 1713206629,
#    'renting': 1,
#    'returning': 1,
#    'uid': '13159'},
#   'free_bikes': 2,
#   'id': 'ab63f92287505218ed77bb453e869afd',
#   'latitude': 51.0614482,
#   'longitude': 3.7485343,
#   'name': 'Antwerpsesteenweg 235',
#   'timestamp': '2024-04-18T00:29:30.701000Z'},
#  {'empty_slots': 3,
#   'extra': {'last_updated': 1713357258,
#    'renting': 1,
#    'returning': 1,
#    'uid': '13395'},
#   'free_bikes': 3,
#   'id': '412fb0879206a060f7c1f89066f24059',
#   'latitude': 51.0352341,
#   'longitude': 3.7303494,
#   'name': 'Lentestraat 35',
#   'timestamp': '2024-04-18T00:29:30.702000Z'},
#  {'empty_slots': 2,
#   'extra': {'last_updated': 1713383061,
#    'renting': 1,
#    'returning': 1,
#    'uid': '13396'},
#   'free_bikes': 1,
#   'id': '70fa8d4e4d0e315c7170f44cd57625b7',
#   'latitude': 51.0402522,
#   'longitude': 3.7189144,
#   'name': 'Filips van Marnixstraat 75',
#   'timestamp': '2024-04-18T00:29:30.703000Z'},
#  {'empty_slots': 5,
#   'extra': {'last_updated': 1713371372,
#    'renting': 1,
#    'returning': 1,
#    'uid': '13258'},
#   'free_bikes': 0,
#   'id': 'a15c6b46db35dd912a911523fd4dd250',
#   'latitude': 51.0347921,
#   'longitude': 3.7258515,
#   'name': 'Zwijnaardsesteenweg 99 ',
#   'timestamp': '2024-04-18T00:29:30.709000Z'},
#  {'empty_slots': 5,
#   'extra': {'last_updated': 1713372304,
#    'renting': 1,
#    'returning': 1,
#    'uid': '13393'},
#   'free_bikes': 1,
#   'id': '24679ae65b0980fd9303ac53387c85a7',
#   'latitude': 51.0545013,
#   'longitude': 3.7444318,
#   'name': 'Neringstraat 2',
#   'timestamp': '2024-04-18T00:29:30.712000Z'},
#  {'empty_slots': 3,
#   'extra': {'last_updated': 1713214440,
#    'renting': 1,
#    'returning': 1,
#    'uid': '13392'},
#   'free_bikes': 0,
#   'id': '2412de399716b248629d2578c30d0b70',
#   'latitude': 51.0447751,
#   'longitude': 3.7001235,
#   'name': 'Europalaan 93',
#   'timestamp': '2024-04-18T00:29:30.713000Z'},
#  {'empty_slots': 2,
#   'extra': {'last_updated': 1713373200,
#    'renting': 1,
#    'returning': 1,
#    'uid': '13251'},
#   'free_bikes': 1,
#   'id': '5b47c24e954a6cf7049e5225843388cc',
#   'latitude': 51.0334311,
#   'longitude': 3.72049,
#   'name': 'Krijgslaan 100',
#   'timestamp': '2024-04-18T00:29:31.286000Z'},
#  {'empty_slots': 3,
#   'extra': {'last_updated': 1713365990,
#    'renting': 1,
#    'returning': 1,
#    'uid': '16663'},
#   'free_bikes': 0,
#   'id': 'dd8907b6f546637904eae930c63f717b',
#   'latitude': 51.0327095,
#   'longitude': 3.7304218,
#   'name': 'Stropstraat 157',
#   'timestamp': '2024-04-18T00:29:30.723000Z'},
#  {'empty_slots': 6,
#   'extra': {'last_updated': 1713364624,
#    'renting': 1,
#    'returning': 1,
#    'uid': '16664'},
#   'free_bikes': 0,
#   'id': 'b18db117450a24de10ebdc07f8d60721',
#   'latitude': 51.0335332,
#   'longitude': 3.7315122,
#   'name': 'Sint-Juliaanstraat 28/32',
#   'timestamp': '2024-04-18T00:29:30.724000Z'},
#  {'empty_slots': 0,
#   'extra': {'last_updated': 1713358341,
#    'renting': 1,
#    'returning': 1,
#    'uid': '16668'},
#   'free_bikes': 6,
#   'id': 'fd9055f8ffc3d10246da2114b6aa2c39',
#   'latitude': 51.0312427,
#   'longitude': 3.7437784,
#   'name': 'Frans de Coninckstraat 5',
#   'timestamp': '2024-04-18T00:29:30.730000Z'},
#  {'empty_slots': 6,
#   'extra': {'last_updated': 1713393880,
#    'renting': 1,
#    'returning': 1,
#    'uid': '13283'},
#   'free_bikes': 1,
#   'id': 'f4d1bb12fd1aaf84e993bbaa9656af13',
#   'latitude': 51.0388912,
#   'longitude': 3.701733,
#   'name': 'Koningin Fabiolalaan 76',
#   'timestamp': '2024-04-18T00:29:30.733000Z'},
#  {'empty_slots': 2,
#   'extra': {'last_updated': 1713160642,
#    'renting': 1,
#    'returning': 1,
#    'uid': '13531'},
#   'free_bikes': 0,
#   'id': 'a653570f7f625a352b81e7548e6107a9',
#   'latitude': 51.0537828,
#   'longitude': 3.7117455,
#   'name': 'Marialand',
#   'timestamp': '2024-04-18T00:29:30.734000Z'},
#  {'empty_slots': 3,
#   'extra': {'last_updated': 1713249739,
#    'renting': 1,
#    'returning': 1,
#    'uid': '16712'},
#   'free_bikes': 0,
#   'id': '6108dfa3fbde59260f4ed9e008e39d88',
#   'latitude': 51.0449118,
#   'longitude': 3.7429104,
#   'name': 'Vlaamsekaai 86',
#   'timestamp': '2024-04-18T00:29:30.742000Z'},
#  {'empty_slots': 3,
#   'extra': {'last_updated': 1713368756,
#    'renting': 1,
#    'returning': 1,
#    'uid': '12005'},
#   'free_bikes': 4,
#   'id': '93af71fd89a2b5c3e8a5ba1aa2f29e2c',
#   'latitude': 51.0579855,
#   'longitude': 3.7193673,
#   'name': 'Sint-Widostraat',
#   'timestamp': '2024-04-18T00:29:30.753000Z'},
#  {'empty_slots': 5,
#   'extra': {'last_updated': 1713293834,
#    'renting': 1,
#    'returning': 1,
#    'uid': '12002'},
#   'free_bikes': 1,
#   'id': '710e516a568381d753fc73954d75421c',
#   'latitude': 51.0460194,
#   'longitude': 3.7027896,
#   'name': 'Yachtdreef',
#   'timestamp': '2024-04-18T00:29:30.755000Z'},
#  {'empty_slots': 6,
#   'extra': {'last_updated': 1713272398,
#    'renting': 1,
#    'returning': 1,
#    'uid': '12003'},
#   'free_bikes': 0,
#   'id': '24638b3101e7b7ff2adb4eab64b77760',
#   'latitude': 51.0525333,
#   'longitude': 3.7229279,
#   'name': 'Sint Niklaasstraat ',
#   'timestamp': '2024-04-18T00:29:30.756000Z'},
#  {'empty_slots': 18,
#   'extra': {'last_updated': 1713363772,
#    'renting': 1,
#    'returning': 1,
#    'uid': '12000'},
#   'free_bikes': 5,
#   'id': '13088b02393576a563630e8eacb9458f',
#   'latitude': 51.0447825,
#   'longitude': 3.6871504,
#   'name': 'Strandlaan 26',
#   'timestamp': '2024-04-18T00:29:30.762000Z'},
#  {'empty_slots': 5,
#   'extra': {'address': ', ',
#    'last_updated': 1713372536,
#    'post_code': '',
#    'renting': 1,
#    'returning': 1,
#    'uid': '23129'},
#   'free_bikes': 5,
#   'id': 'fb1e1c1a98357e8db2c8c39e4b37974b',
#   'latitude': 51.0364314,
#   'longitude': 3.7130812,
#   'name': '3de Gent-Sint-Pietersstation Noord',
#   'timestamp': '2024-04-18T00:29:30.763000Z'},
#  {'empty_slots': 3,
#   'extra': {'last_updated': 1712930998,
#    'renting': 1,
#    'returning': 1,
#    'uid': '13324'},
#   'free_bikes': 0,
#   'id': '48b6902234b2c85bcfd40df4593101a4',
#   'latitude': 51.0472983,
#   'longitude': 3.7337091,
#   'name': 'Sint-Annastraat 3',
#   'timestamp': '2024-04-18T00:29:30.790000Z'},
#  {'empty_slots': 3,
#   'extra': {'last_updated': 1713375733,
#    'renting': 1,
#    'returning': 1,
#    'uid': '13325'},
#   'free_bikes': 3,
#   'id': 'd11d22de75282c7c05798b62807a5a3c',
#   'latitude': 51.0560957,
#   'longitude': 3.7444236,
#   'name': 'Wasstraat 116',
#   'timestamp': '2024-04-18T00:29:30.792000Z'},
#  {'empty_slots': 3,
#   'extra': {'last_updated': 1712988314,
#    'renting': 1,
#    'returning': 1,
#    'uid': '13322'},
#   'free_bikes': 0,
#   'id': '75db5d57566cc06f7664b91d1ab56c51',
#   'latitude': 51.0425649,
#   'longitude': 3.7366551,
#   'name': 'Ommegangstraat 2',
#   'timestamp': '2024-04-18T00:29:30.804000Z'},
#  {'empty_slots': 1,
#   'extra': {'address': ', ',
#    'last_updated': 1713396303,
#    'post_code': '',
#    'renting': 1,
#    'returning': 1,
#    'uid': '13286'},
#   'free_bikes': 2,
#   'id': '86467c41b30e470c56fb762eab15fac8',
#   'latitude': 51.0417894,
#   'longitude': 3.7068596,
#   'name': 'Sportstraat 212',
#   'timestamp': '2024-04-18T00:29:30.814000Z'},
#  {'empty_slots': 10,
#   'extra': {'last_updated': 1713368982,
#    'renting': 1,
#    'returning': 1,
#    'uid': '15559'},
#   'free_bikes': 2,
#   'id': 'ed8a2373c39ef8d3f79a878e073dfa61',
#   'latitude': 51.0240214,
#   'longitude': 3.713336,
#   'name': 'Sterre Zuid',
#   'timestamp': '2024-04-18T00:29:30.815000Z'},
#  {'empty_slots': 10,
#   'extra': {'last_updated': 1713360551,
#    'renting': 1,
#    'returning': 1,
#    'uid': '15558'},
#   'free_bikes': 3,
#   'id': 'eaa6b245ee62c45784f77efbb12271ec',
#   'latitude': 51.0262373,
#   'longitude': 3.7128156,
#   'name': 'Sterre Noord',
#   'timestamp': '2024-04-18T00:29:30.828000Z'},
#  {'empty_slots': 1,
#   'extra': {'last_updated': 1713265862,
#    'renting': 1,
#    'returning': 1,
#    'uid': '12139'},
#   'free_bikes': 2,
#   'id': 'fdd045998e6d644711170bf8238e8f36',
#   'latitude': 51.042648,
#   'longitude': 3.7104159,
#   'name': 'Gordunakaai 1',
#   'timestamp': '2024-04-18T00:29:30.833000Z'},
#  {'empty_slots': 3,
#   'extra': {'last_updated': 1713154117,
#    'renting': 1,
#    'returning': 1,
#    'uid': '12133'},
#   'free_bikes': 0,
#   'id': '4566bdaafaefa59d531d3c37d3d9eec7',
#   'latitude': 51.0602159,
#   'longitude': 3.6949114,
#   'name': 'Meibloemstraat 120',
#   'timestamp': '2024-04-18T00:29:30.839000Z'},
#  {'empty_slots': 5,
#   'extra': {'last_updated': 1713370494,
#    'renting': 1,
#    'returning': 1,
#    'uid': '12130'},
#   'free_bikes': 2,
#   'id': '65e05d4cbe334ce8c884fd37ed00b328',
#   'latitude': 51.0553219,
#   'longitude': 3.697488,
#   'name': 'Kaarderijstraat 31',
#   'timestamp': '2024-04-18T00:29:30.841000Z'},
#  {'empty_slots': 4,
#   'extra': {'last_updated': 1713388566,
#    'renting': 1,
#    'returning': 1,
#    'uid': '12131'},
#   'free_bikes': 1,
#   'id': '7c74633c0a25be37e476016517c052ea',
#   'latitude': 51.0585863,
#   'longitude': 3.7022347,
#   'name': 'Haspelstraat 49',
#   'timestamp': '2024-04-18T00:29:30.861000Z'},
#  {'empty_slots': 4,
#   'extra': {'last_updated': 1713374598,
#    'renting': 1,
#    'returning': 1,
#    'uid': '12137'},
#   'free_bikes': 2,
#   'id': '6a9fec262669a8655ed0199316c51c37',
#   'latitude': 51.0366249,
#   'longitude': 3.7166989,
#   'name': 'Fortlaan Citadelpark',
#   'timestamp': '2024-04-18T00:29:30.862000Z'},
#  {'empty_slots': 3,
#   'extra': {'last_updated': 1713372607,
#    'renting': 1,
#    'returning': 1,
#    'uid': '12135'},
#   'free_bikes': 0,
#   'id': '16aa1ecb3616ddbb12d7c8c5d69cdca5',
#   'latitude': 51.0302418,
#   'longitude': 3.7060293,
#   'name': 'Voskenslaan 183',
#   'timestamp': '2024-04-18T00:29:30.864000Z'},
#  {'empty_slots': 3,
#   'extra': {'last_updated': 1713367848,
#    'renting': 1,
#    'returning': 1,
#    'uid': '12132'},
#   'free_bikes': 0,
#   'id': '3de3303cc39dc978396676413e161261',
#   'latitude': 51.0581844,
#   'longitude': 3.6986053,
#   'name': 'Ooievaarstraat 66',
#   'timestamp': '2024-04-18T00:29:30.835000Z'},
#  {'empty_slots': 11,
#   'extra': {'last_updated': 1713195294,
#    'renting': 1,
#    'returning': 1,
#    'uid': '23235'},
#   'free_bikes': 1,
#   'id': '70a5262d46266753caed1fcf835814b5',
#   'latitude': 51.0348576,
#   'longitude': 3.7553025,
#   'name': 'P+R E17 Gentbrugge',
#   'timestamp': '2024-04-18T00:29:30.890000Z'},
#  {'empty_slots': 3,
#   'extra': {'last_updated': 1713359022,
#    'renting': 1,
#    'returning': 1,
#    'uid': '13212'},
#   'free_bikes': 0,
#   'id': '0837c7e59c8a9b0e26ea6b114e6fff3c',
#   'latitude': 51.0729727,
#   'longitude': 3.7097549,
#   'name': 'Edmond Van Beverenplein 7',
#   'timestamp': '2024-04-18T00:29:30.892000Z'},
#  {'empty_slots': 1,
#   'extra': {'last_updated': 1713380096,
#    'renting': 1,
#    'returning': 1,
#    'uid': '13215'},
#   'free_bikes': 5,
#   'id': '16792b84fd889a2b1428e2659ff699bd',
#   'latitude': 51.0676195,
#   'longitude': 3.70002,
#   'name': 'Welvaartstraat 1 ',
#   'timestamp': '2024-04-18T00:29:30.901000Z'},
#  {'empty_slots': 3,
#   'extra': {'last_updated': 1713034158,
#    'renting': 1,
#    'returning': 1,
#    'uid': '13216'},
#   'free_bikes': 0,
#   'id': '0858f39570fc54992ae282ddb6107b9c',
#   'latitude': 51.0591027,
#   'longitude': 3.6923874,
#   'name': 'Peerstraat 2',
#   'timestamp': '2024-04-18T00:29:30.902000Z'},
#  {'empty_slots': 2,
#   'extra': {'last_updated': 1713391148,
#    'renting': 1,
#    'returning': 1,
#    'uid': '13193'},
#   'free_bikes': 1,
#   'id': '30527cbb6b8450a98f14c30b9bcfdfd1',
#   'latitude': 51.05023,
#   'longitude': 3.7526381,
#   'name': 'Gentbruggestraat 90',
#   'timestamp': '2024-04-18T00:29:30.905000Z'},
#  {'empty_slots': 1,
#   'extra': {'last_updated': 1713157567,
#    'renting': 1,
#    'returning': 1,
#    'uid': '13192'},
#   'free_bikes': 2,
#   'id': 'f45fe8b31cc637ae07751c634699aeed',
#   'latitude': 51.0494013,
#   'longitude': 3.7597954,
#   'name': 'Emiel Lossystraat 55h',
#   'timestamp': '2024-04-18T00:29:31.170000Z'},
#  {'empty_slots': 0,
#   'extra': {'last_updated': 1713036719,
#    'renting': 1,
#    'returning': 1,
#    'uid': '13190'},
#   'free_bikes': 3,
#   'id': 'f3e2c03768168f204f28e72844f796f3',
#   'latitude': 51.0476303,
#   'longitude': 3.7511836,
#   'name': 'Wolterslaan 160',
#   'timestamp': '2024-04-18T00:29:30.916000Z'},
#  {'empty_slots': 5,
#   'extra': {'last_updated': 1713250895,
#    'renting': 1,
#    'returning': 1,
#    'uid': '13196'},
#   'free_bikes': 1,
#   'id': '25a130c9cfae8ee8b39a38d3c4698175',
#   'latitude': 51.0440985,
#   'longitude': 3.7494853,
#   'name': 'Kerkstraat 130',
#   'timestamp': '2024-04-18T00:29:30.917000Z'},
#  {'empty_slots': 6,
#   'extra': {'address': ', ',
#    'last_updated': 1713266735,
#    'post_code': '',
#    'renting': 1,
#    'returning': 1,
#    'uid': '13195'},
#   'free_bikes': 0,
#   'id': '7cad2bed83414886e94e9f3852750b02',
#   'latitude': 51.0455618,
#   'longitude': 3.7477834,
#   'name': 'Bassijnstraat 2',
#   'timestamp': '2024-04-18T00:29:30.918000Z'},
#  {'empty_slots': 0,
#   'extra': {'last_updated': 1713189292,
#    'renting': 1,
#    'returning': 1,
#    'uid': '23834'},
#   'free_bikes': 3,
#   'id': '306d129bbe946a0cfdbeda0257d9f90f',
#   'latitude': 51.0231244,
#   'longitude': 3.6989272,
#   'name': 'Tramhalte Don Bosco',
#   'timestamp': '2024-04-18T00:29:30.919000Z'},
#  {'empty_slots': 1,
#   'extra': {'last_updated': 1713196068,
#    'renting': 1,
#    'returning': 1,
#    'uid': '22292'},
#   'free_bikes': 2,
#   'id': '59cfef6dde0ede6816726679a3a0aaa2',
#   'latitude': 51.0646903,
#   'longitude': 3.7521296,
#   'name': 'Verkortingstraat 102',
#   'timestamp': '2024-04-18T00:29:30.920000Z'},
#  {'empty_slots': 1,
#   'extra': {'last_updated': 1713376955,
#    'renting': 1,
#    'returning': 1,
#    'uid': '23838'},
#   'free_bikes': 2,
#   'id': 'ce7c8da008cd4743ef78d7cb694dd201',
#   'latitude': 51.0614386,
#   'longitude': 3.7202492,
#   'name': 'Az Sint Lucas ',
#   'timestamp': '2024-04-18T00:29:30.921000Z'},
#  {'empty_slots': 2,
#   'extra': {'address': ', ',
#    'last_updated': 1713345016,
#    'post_code': '',
#    'renting': 1,
#    'returning': 1,
#    'uid': '13267'},
#   'free_bikes': 1,
#   'id': 'f8f4d44802ae144e59808bccd285fa47',
#   'latitude': 51.056694,
#   'longitude': 3.7355042,
#   'name': 'Jan van Gentstraat 36',
#   'timestamp': '2024-04-18T00:29:30.923000Z'},
#  {'empty_slots': 6,
#   'extra': {'last_updated': 1713351372,
#    'renting': 1,
#    'returning': 1,
#    'uid': '13260'},
#   'free_bikes': 0,
#   'id': 'bbc2bc4378ed920e8034be8f3e905443',
#   'latitude': 51.0351541,
#   'longitude': 3.7151205,
#   'name': 'Oostendestraat 91',
#   'timestamp': '2024-04-18T00:29:30.928000Z'},
#  {'empty_slots': 0,
#   'extra': {'last_updated': 1713384715,
#    'renting': 1,
#    'returning': 1,
#    'uid': '13268'},
#   'free_bikes': 3,
#   'id': '07006d4c2648720f7ee0ee3baec5a1b0',
#   'latitude': 51.0411883,
#   'longitude': 3.7152769,
#   'name': 'Beemdstraat 5',
#   'timestamp': '2024-04-18T00:29:30.929000Z'},
#  {'empty_slots': 13,
#   'extra': {'last_updated': 1713394200,
#    'renting': 1,
#    'returning': 1,
#    'uid': '18654'},
#   'free_bikes': 11,
#   'id': '2c71223d86e73df9207c3fbe5b81a1d6',
#   'latitude': 51.0465209,
#   'longitude': 3.7270528,
#   'name': 'Sint-Pietersnieuwstraat 35',
#   'timestamp': '2024-04-18T00:29:30.930000Z'},
#  {'empty_slots': 6,
#   'extra': {'last_updated': 1713361405,
#    'renting': 1,
#    'returning': 1,
#    'uid': '18657'},
#   'free_bikes': 0,
#   'id': 'e8df6ff566c6126e4ce3f8c42528a1b5',
#   'latitude': 51.0426564,
#   'longitude': 3.7274674,
#   'name': 'Tweekerkenstraat',
#   'timestamp': '2024-04-18T00:29:30.931000Z'},
#  {'empty_slots': 5,
#   'extra': {'last_updated': 1713379732,
#    'renting': 1,
#    'returning': 1,
#    'uid': '19923'},
#   'free_bikes': 1,
#   'id': 'db7e28dfd241236f6d2e642c5c23106c',
#   'latitude': 51.0419677,
#   'longitude': 3.7397721,
#   'name': 'Keizervest 1',
#   'timestamp': '2024-04-18T00:29:30.932000Z'},
#  {'empty_slots': 2,
#   'extra': {'last_updated': 1713392176,
#    'renting': 1,
#    'returning': 1,
#    'uid': '18302'},
#   'free_bikes': 1,
#   'id': 'bcd66f162c4f4f4f704d85ebe9fac6bb',
#   'latitude': 51.0421195,
#   'longitude': 3.7197052,
#   'name': 'Laurent Delvaux straat 5',
#   'timestamp': '2024-04-18T00:29:30.933000Z'},
#  {'empty_slots': 4,
#   'extra': {'last_updated': 1713377737,
#    'renting': 1,
#    'returning': 1,
#    'uid': '18301'},
#   'free_bikes': 2,
#   'id': 'ea3fa0ae52bafccec22bf0737c4b4ca3',
#   'latitude': 51.0648827,
#   'longitude': 3.7379278,
#   'name': 'Kompasplein',
#   'timestamp': '2024-04-18T00:29:30.934000Z'},
#  {'empty_slots': 11,
#   'extra': {'last_updated': 1713379677,
#    'renting': 1,
#    'returning': 1,
#    'uid': '18659'},
#   'free_bikes': 1,
#   'id': 'b75a971f9e7074b0fdc889855fcb98e9',
#   'latitude': 51.0461967,
#   'longitude': 3.7250625,
#   'name': 'Jozef Plateaustraat 45',
#   'timestamp': '2024-04-18T00:29:30.934000Z'},
#  {'empty_slots': 9,
#   'extra': {'last_updated': 1713376657,
#    'renting': 1,
#    'returning': 1,
#    'uid': '18658'},
#   'free_bikes': 3,
#   'id': '7386e354edbb081c386cfeb5f16a3345',
#   'latitude': 51.0440229,
#   'longitude': 3.7251746,
#   'name': 'Blandijnberg 2',
#   'timestamp': '2024-04-18T00:29:30.935000Z'},
#  {'empty_slots': 2,
#   'extra': {'last_updated': 1713138903,
#    'renting': 1,
#    'returning': 1,
#    'uid': '12047'},
#   'free_bikes': 1,
#   'id': '50ea374a6308157d7116b3f28235a516',
#   'latitude': 51.0449481,
#   'longitude': 3.728668,
#   'name': 'Muinkkaai 34',
#   'timestamp': '2024-04-18T00:29:30.940000Z'},
#  {'empty_slots': 3,
#   'extra': {'last_updated': 1713387349,
#    'renting': 1,
#    'returning': 1,
#    'uid': '16613'},
#   'free_bikes': 1,
#   'id': '94e5f5c27de40e0341b56899409c8a86',
#   'latitude': 51.0485769,
#   'longitude': 3.7094228,
#   'name': 'Martelaarslaan 406',
#   'timestamp': '2024-04-18T00:29:30.942000Z'},
#  {'empty_slots': 3,
#   'extra': {'last_updated': 1713388892,
#    'renting': 1,
#    'returning': 1,
#    'uid': '16611'},
#   'free_bikes': 1,
#   'id': '79644c45b412cb483fcf7b922ad29f8a',
#   'latitude': 51.0521476,
#   'longitude': 3.7028285,
#   'name': 'Koolkapperstraat 18',
#   'timestamp': '2024-04-18T00:29:30.944000Z'},
#  {'empty_slots': 3,
#   'extra': {'last_updated': 1713380546,
#    'renting': 1,
#    'returning': 1,
#    'uid': '16610'},
#   'free_bikes': 1,
#   'id': '2b4f9b13dd287d944a25e400eb144f1b',
#   'latitude': 51.0579847,
#   'longitude': 3.704422,
#   'name': 'Portugalstraat 13',
#   'timestamp': '2024-04-18T00:29:30.945000Z'},
#  {'empty_slots': 3,
#   'extra': {'last_updated': 1713251609,
#    'renting': 1,
#    'returning': 1,
#    'uid': '23901'},
#   'free_bikes': 0,
#   'id': '512ca6395b9e7115aa29a336c64003d1',
#   'latitude': 51.0429092,
#   'longitude': 3.73865,
#   'name': 'Artevelde Hogeschool Brusselsepoortstraat',
#   'timestamp': '2024-04-18T00:29:30.955000Z'},
#  {'empty_slots': 2,
#   'extra': {'last_updated': 1713369683,
#    'renting': 1,
#    'returning': 1,
#    'uid': '22599'},
#   'free_bikes': 1,
#   'id': 'a0791ee328d28e17bd311521f529cccf',
#   'latitude': 51.0534975,
#   'longitude': 3.7314845,
#   'name': 'keizerkarelstraat 1 ',
#   'timestamp': '2024-04-18T00:29:30.958000Z'},
#  {'empty_slots': 0,
#   'extra': {'last_updated': 1713391549,
#    'renting': 1,
#    'returning': 1,
#    'uid': '12767'},
#   'free_bikes': 3,
#   'id': '2ba7e8a05a2242ef8d66f88b8d1c70b4',
#   'latitude': 51.0446084,
#   'longitude': 3.7587073,
#   'name': 'Emanuel Hielstraat 30',
#   'timestamp': '2024-04-18T00:29:30.959000Z'},
#  {'empty_slots': 5,
#   'extra': {'last_updated': 1713377528,
#    'renting': 1,
#    'returning': 1,
#    'uid': '18784'},
#   'free_bikes': 2,
#   'id': '8e76c111b7d9c76e7c39288abcb4e0b0',
#   'latitude': 51.0666684,
#   'longitude': 3.7319924,
#   'name': 'Dok Noord 2',
#   'timestamp': '2024-04-18T00:29:30.967000Z'},
#  {'empty_slots': 6,
#   'extra': {'last_updated': 1713389818,
#    'renting': 1,
#    'returning': 1,
#    'uid': '16476'},
#   'free_bikes': 0,
#   'id': '65045dbf2f556e03b40428ee0470c28c',
#   'latitude': 51.0331016,
#   'longitude': 3.7238981,
#   'name': 'Corbiestraat 36',
#   'timestamp': '2024-04-18T00:29:30.968000Z'},
#  {'empty_slots': 3,
#   'extra': {'last_updated': 1713263639,
#    'renting': 1,
#    'returning': 1,
#    'uid': '20840'},
#   'free_bikes': 0,
#   'id': 'c9dba34e928ed1f54249921cc8d1056a',
#   'latitude': 51.0455266,
#   'longitude': 3.7186354,
#   'name': 'KASK',
# ...
#   'latitude': 51.0571073,
#   'longitude': 3.7286481,
#   'name': 'Bibliotheekstraat 1',
#   'timestamp': '2024-04-18T00:29:31.332000Z'},
#  {'empty_slots': 6,
#   'extra': {'last_updated': 1713383424,
#    'renting': 1,
#    'returning': 1,
#    'uid': '12079'},
#   'free_bikes': 0,
#   'id': '32a39e2eafdfec534f7e1464f3a2709b',
#   'latitude': 51.0642826,
#   'longitude': 3.7339905,
#   'name': 'Stapelplein 31',
#   'timestamp': '2024-04-18T00:29:31.194000Z'},
#  {'empty_slots': 4,
#   'extra': {'last_updated': 1713281250,
#    'renting': 1,
#    'returning': 1,
#    'uid': '12027'},
#   'free_bikes': 2,
#   'id': '8ccb9e87988d980a65b293559465106c',
#   'latitude': 51.0570081,
#   'longitude': 3.7329869,
#   'name': 'Ham 1',
#   'timestamp': '2024-04-18T00:29:30.965000Z'},
#  {'empty_slots': 3,
#   'extra': {'last_updated': 1713377615,
#    'renting': 1,
#    'returning': 1,
#    'uid': '12116'},
#   'free_bikes': 2,
#   'id': 'c7a33e9048543382212a9902050c99b9',
#   'latitude': 51.0575622,
#   'longitude': 3.7391434,
#   'name': 'Kleindokkaai zuid',
#   'timestamp': '2024-04-18T00:29:31.346000Z'},
#  {'empty_slots': 2,
#   'extra': {'last_updated': 1713295382,
#    'renting': 1,
#    'returning': 1,
#    'uid': '16695'},
#   'free_bikes': 1,
#   'id': '128976b8ab791b64fb935e7861d30fcd',
#   'latitude': 51.0606404,
#   'longitude': 3.7310502,
#   'name': 'Kongostraat 7',
#   'timestamp': '2024-04-18T00:29:30.635000Z'},
#  {'empty_slots': 3,
#   'extra': {'last_updated': 1713387438,
#    'renting': 1,
#    'returning': 1,
#    'uid': '23926'},
#   'free_bikes': 0,
#   'id': '3fa0fc23273ba6b0e9715ee6d1c6bfe9',
#   'latitude': 51.0642746,
#   'longitude': 3.7074351,
#   'name': 'schommelstraat 46',
#   'timestamp': '2024-04-18T00:29:31.334000Z'},
#  {'empty_slots': 1,
#   'extra': {'last_updated': 1713361501,
#    'renting': 1,
#    'returning': 1,
#    'uid': '12025'},
#   'free_bikes': 5,
#   'id': '2f01326108355b3313a566408746fca6',
#   'latitude': 51.0539409,
#   'longitude': 3.7251371,
#   'name': 'Goudenleeuwplein 1',
#   'timestamp': '2024-04-18T00:29:31.314000Z'},
#  {'empty_slots': 3,
#   'extra': {'last_updated': 1713383170,
#    'renting': 1,
#    'returning': 1,
#    'uid': '27879'},
#   'free_bikes': 0,
#   'id': 'bfeab016f261b5c8b8e16dcc4fdb8ae8',
#   'latitude': 51.0643085,
#   'longitude': 3.7316159,
#   'name': 'Denise de weerdtpad',
#   'timestamp': '2024-04-18T00:29:30.547000Z'},
#  {'empty_slots': 3,
#   'extra': {'last_updated': 1713047313,
#    'renting': 1,
#    'returning': 1,
#    'uid': '14399'},
#   'free_bikes': 0,
#   'id': '62c4fbd3bd3bd67fc308fc6215b9056a',
#   'latitude': 51.0497677,
#   'longitude': 3.6921909,
#   'name': 'Noorderlaan 10',
#   'timestamp': '2024-04-18T00:29:30.617000Z'},
#  {'empty_slots': 3,
#   'extra': {'last_updated': 1713358022,
#    'renting': 1,
#    'returning': 1,
#    'uid': '28483'},
#   'free_bikes': 0,
#   'id': '0f070dedd2e6f89d15f5180d5e77fbd3',
#   'latitude': 51.0537055,
#   'longitude': 3.6911578,
#   'name': 'Jenny Montignypad',
#   'timestamp': '2024-04-18T00:29:31.253000Z'},
#  {'empty_slots': 1,
#   'extra': {'last_updated': 1713389694,
#    'renting': 1,
#    'returning': 1,
#    'uid': '28482'},
#   'free_bikes': 2,
#   'id': '7b50c5e11ea7806c5acd67faec766831',
#   'latitude': 51.0477213,
#   'longitude': 3.7075371,
#   'name': 'Delhaize Watersportbaan',
#   'timestamp': '2024-04-18T00:29:31.255000Z'},
#  {'empty_slots': 3,
#   'extra': {'last_updated': 1713362073,
#    'renting': 1,
#    'returning': 1,
#    'uid': '28484'},
#   'free_bikes': 1,
#   'id': '4b7cf8dd3184bac628596bb96541be2b',
#   'latitude': 51.0537679,
#   'longitude': 3.6880481,
#   'name': 'Lily Boeykensstraat',
#   'timestamp': '2024-04-18T00:29:31.267000Z'},
#  {'empty_slots': 2,
#   'extra': {'last_updated': 1712750410,
#    'renting': 1,
#    'returning': 1,
#    'uid': '28486'},
#   'free_bikes': 1,
#   'id': '3007da6e68ee6d7666da692c8c7d672d',
#   'latitude': 51.0729584,
#   'longitude': 3.6764147,
#   'name': 'Elfnovemberlaan',
#   'timestamp': '2024-04-18T00:29:30.370000Z'},
#  {'empty_slots': 1,
#   'extra': {'last_updated': 1713154644,
#    'renting': 1,
#    'returning': 1,
#    'uid': '28485'},
#   'free_bikes': 2,
#   'id': '9545faef8f05f1e04c1c3fe863d8f866',
#   'latitude': 51.0720396,
#   'longitude': 3.6805406,
#   'name': 'Mauriceclaeysplein',
#   'timestamp': '2024-04-18T00:29:30.371000Z'},
#  {'empty_slots': 3,
#   'extra': {'last_updated': 1713042542,
#    'renting': 1,
#    'returning': 1,
#    'uid': '13219'},
#   'free_bikes': 0,
#   'id': '94badc4fa879e5966fd0a2261d057c4d',
#   'latitude': 51.0564994,
#   'longitude': 3.6932704,
#   'name': 'Schaverdijnstraat 43',
#   'timestamp': '2024-04-18T00:29:30.912000Z'},
#  {'empty_slots': 2,
#   'extra': {'last_updated': 1713352931,
#    'renting': 1,
#    'returning': 1,
#    'uid': '28487'},
#   'free_bikes': 1,
#   'id': '4a2da4a9a871d905c90dd01a19a30362',
#   'latitude': 51.0524697,
#   'longitude': 3.694065,
#   'name': 'Curcuskerk Malem',
#   'timestamp': '2024-04-18T00:29:31.264000Z'},
#  {'empty_slots': 2,
#   'extra': {'last_updated': 1713359725,
#    'renting': 1,
#    'returning': 1,
#    'uid': '28488'},
#   'free_bikes': 1,
#   'id': '38cdb34cfc82a1860bab64a1f78149bc',
#   'latitude': 51.0747188,
#   'longitude': 3.701488,
#   'name': 'Van Peenestraat 2',
#   'timestamp': '2024-04-18T00:29:31.269000Z'},
#  {'empty_slots': 2,
#   'extra': {'last_updated': 1713213725,
#    'renting': 1,
#    'returning': 1,
#    'uid': '12416'},
#   'free_bikes': 0,
#   'id': '60bbbc2774116b2faaa9f7a8357fc35f',
#   'latitude': 51.0629757,
#   'longitude': 3.7039096,
#   'name': 'Pannestraat 1',
#   'timestamp': '2024-04-18T00:29:31.388000Z'},
#  {'empty_slots': 2,
#   'extra': {'last_updated': 1713368628,
#    'renting': 1,
#    'returning': 1,
#    'uid': '12402'},
#   'free_bikes': 2,
#   'id': 'd84b81badb9e1939412bd973a5491ea8',
#   'latitude': 51.0613672,
#   'longitude': 3.715495,
#   'name': 'Kolveniersgang 133',
#   'timestamp': '2024-04-18T00:29:30.659000Z'},
#  {'empty_slots': 1,
#   'extra': {'last_updated': 1713378225,
#    'renting': 1,
#    'returning': 1,
#    'uid': '12401'},
#   'free_bikes': 2,
#   'id': 'c961c25534b587be5324fbf45a4f39f0',
#   'latitude': 51.0641446,
#   'longitude': 3.7186509,
#   'name': 'Molenaarsstraat 125',
#   'timestamp': '2024-04-18T00:29:30.663000Z'},
#  {'empty_slots': 8,
#   'extra': {'last_updated': 1713200401,
#    'renting': 1,
#    'returning': 1,
#    'uid': '12393'},
#   'free_bikes': 0,
#   'id': '1fd680ff48ed74e28e852392f5960c12',
#   'latitude': 51.0649386,
#   'longitude': 3.7175553,
#   'name': 'Opgeëistenlaan 457',
#   'timestamp': '2024-04-18T00:29:31.251000Z'},
#  {'empty_slots': 3,
#   'extra': {'last_updated': 1711930725,
#    'renting': 1,
#    'returning': 1,
#    'uid': '28489'},
#   'free_bikes': 0,
#   'id': '25b9117c7543fb5fbb32dc2ff13e0d99',
#   'latitude': 51.066051,
#   'longitude': 3.7155223,
#   'name': 'Tondelierlaan',
#   'timestamp': '2024-04-18T00:29:31.268000Z'},
#  {'empty_slots': 3,
#   'extra': {'last_updated': 1713386732,
#    'renting': 1,
#    'returning': 1,
#    'uid': '28490'},
#   'free_bikes': 1,
#   'id': '4fb2d710c4c0bcbfd820658a7cf3582b',
#   'latitude': 51.0768428,
#   'longitude': 3.7286531,
#   'name': 'Bombaystraat',
#   'timestamp': '2024-04-18T00:29:30.475000Z'},
#  {'empty_slots': 2,
#   'extra': {'last_updated': 1713355228,
#    'renting': 1,
#    'returning': 1,
#    'uid': '28491'},
#   'free_bikes': 1,
#   'id': '2459061a75c4d843bac38e5962b579e4',
#   'latitude': 51.0858467,
#   'longitude': 3.7272912,
#   'name': 'De Waterspiegel',
#   'timestamp': '2024-04-18T00:29:31.168000Z'},
#  {'empty_slots': 3,
#   'extra': {'last_updated': 1713390193,
#    'renting': 1,
#    'returning': 1,
#    'uid': '28494'},
#   'free_bikes': 1,
#   'id': '0f6728e92437a8e0bd6be2a5df846d1e',
#   'latitude': 51.0489453,
#   'longitude': 3.7378373,
#   'name': 'Visserij - Tweebruggenstraat',
#   'timestamp': '2024-04-18T00:29:30.455000Z'},
#  {'empty_slots': 0,
#   'extra': {'last_updated': 1713342732,
#    'renting': 1,
#    'returning': 1,
#    'uid': '28493'},
#   'free_bikes': 3,
#   'id': 'cd32c020839c22b3edbe6be8b23d268c',
#   'latitude': 51.0532448,
#   'longitude': 3.7336292,
#   'name': 'Gebroeders Van Eyckstraat',
#   'timestamp': '2024-04-18T00:29:30.482000Z'},
#  {'empty_slots': 2,
#   'extra': {'last_updated': 1713386163,
#    'renting': 1,
#    'returning': 1,
#    'uid': '28495'},
#   'free_bikes': 2,
#   'id': 'e5cfc96474e073b8409dfadb940aa9ed',
#   'latitude': 51.0471478,
#   'longitude': 3.7440942,
#   'name': 'Zalmstraat 71',
#   'timestamp': '2024-04-18T00:29:30.464000Z'},
#  {'empty_slots': 3,
#   'extra': {'last_updated': 1710834099,
#    'renting': 1,
#    'returning': 1,
#    'uid': '28496'},
#   'free_bikes': 0,
#   'id': '7e50d19a9f3bd5105a2f384d85194519',
#   'latitude': 51.0440489,
#   'longitude': 3.7360865,
#   'name': 'Clarissenstraat',
#   'timestamp': '2024-04-18T00:29:30.468000Z'},
#  {'empty_slots': 3,
#   'extra': {'last_updated': 1713057187,
#    'renting': 1,
#    'returning': 1,
#    'uid': '12768'},
#   'free_bikes': 0,
#   'id': '802a950e251aac934c7c0e382fbea282',
#   'latitude': 51.0406115,
#   'longitude': 3.7557693,
#   'name': 'Frederik Burvenichstraat 184',
#   'timestamp': '2024-04-18T00:29:31.319000Z'},
#  {'empty_slots': 3,
#   'extra': {'last_updated': 1713217207,
#    'renting': 1,
#    'returning': 1,
#    'uid': '28497'},
#   'free_bikes': 0,
#   'id': '63b7edd173f2c591d31d6c353c47bc9e',
#   'latitude': 51.0431988,
#   'longitude': 3.7359775,
#   'name': 'Hendrik Waelputstraat14',
#   'timestamp': '2024-04-18T00:29:30.473000Z'},
#  {'empty_slots': 5,
#   'extra': {'last_updated': 1713382569,
#    'renting': 1,
#    'returning': 1,
#    'uid': '28502'},
#   'free_bikes': 1,
#   'id': '1db0822ee66df4367df7cd46b9192aa9',
#   'latitude': 51.0317333,
#   'longitude': 3.707246,
#   'name': 'Tuinwijklaan-Voskeslaan',
#   'timestamp': '2024-04-18T00:29:31.185000Z'},
#  {'empty_slots': 3,
#   'extra': {'last_updated': 1713093172,
#    'renting': 1,
#    'returning': 1,
#    'uid': '28503'},
#   'free_bikes': 0,
#   'id': '57c9a1470ab221967af26469f843acae',
#   'latitude': 51.0232117,
#   'longitude': 3.7203362,
#   'name': 'Rerum-Novarumplein',
#   'timestamp': '2024-04-18T00:29:31.186000Z'},
#  {'empty_slots': 2,
#   'extra': {'last_updated': 1713336551,
#    'renting': 1,
#    'returning': 1,
#    'uid': '23906'},
#   'free_bikes': 1,
#   'id': '4b4315cfa207008c49fd231b5f8dd61d',
#   'latitude': 51.0419757,
#   'longitude': 3.7243206,
#   'name': 'Blok E artevelde',
#   'timestamp': '2024-04-18T00:29:31.333000Z'},
#  {'empty_slots': 2,
#   'extra': {'last_updated': 1713370671,
#    'renting': 1,
#    'returning': 1,
#    'uid': '13217'},
#   'free_bikes': 2,
#   'id': '2a2ea60ba5d2b374589dcfab27a2160e',
#   'latitude': 51.0292757,
#   'longitude': 3.7222556,
#   'name': 'Zwijnaardsesteenweg 316d',
#   'timestamp': '2024-04-18T00:29:30.903000Z'},
#  {'empty_slots': 3,
#   'extra': {'last_updated': 1713155350,
#    'renting': 1,
#    'returning': 1,
#    'uid': '28504'},
#   'free_bikes': 0,
#   'id': 'bbe7a2ab620ae3320d04dedddcb9345d',
#   'latitude': 51.0228408,
#   'longitude': 3.7227056,
#   'name': 'Steenakker 78',
#   'timestamp': '2024-04-18T00:29:31.038000Z'},
#  {'empty_slots': 2,
#   'extra': {'last_updated': 1712960007,
#    'renting': 1,
#    'returning': 1,
#    'uid': '13248'},
#   'free_bikes': 1,
#   'id': 'd7e96d6450b9e19aefcd10b6bc1b5134',
#   'latitude': 51.0530727,
#   'longitude': 3.7551516,
#   'name': 'Adolf Baeyensstraat 186',
#   'timestamp': '2024-04-18T00:29:30.369000Z'},
#  {'empty_slots': 20,
#   'extra': {'address': ', ',
#    'last_updated': 1713389352,
#    'post_code': '',
#    'renting': 1,
#    'returning': 1,
#    'uid': '17178'},
#   'free_bikes': 3,
#   'id': 'c0a7097988f9176aa6ce60305b082284',
#   'latitude': 51.0566701,
#   'longitude': 3.7401091,
#   'name': 'Station Dampoort',
#   'timestamp': '2024-04-18T00:29:31.376000Z'},
#  {'empty_slots': 3,
#   'extra': {'last_updated': 1713123183,
#    'renting': 1,
#    'returning': 1,
#    'uid': '28522'},
#   'free_bikes': 0,
#   'id': '17811174d4c7ed6b666c826fefd30903',
#   'latitude': 51.049723,
#   'longitude': 3.7140122,
#   'name': 'Krommenelleboog',
#   'timestamp': '2024-04-18T00:29:30.732000Z'},
#  {'empty_slots': 3,
#   'extra': {'last_updated': 1713285289,
#    'renting': 1,
#    'returning': 1,
#    'uid': '28541'},
#   'free_bikes': 0,
#   'id': 'de5ac9fc0737dbe60a2fda6017880118',
#   'latitude': 51.0541799,
#   'longitude': 3.7063884,
#   'name': 'Pieter Colpaertsteeg 52',
#   'timestamp': '2024-04-18T00:29:31.292000Z'},
#  {'empty_slots': 3,
#   'extra': {'last_updated': 1713394148,
#    'renting': 1,
#    'returning': 1,
#    'uid': '28554'},
#   'free_bikes': 1,
#   'id': 'd92e0942624a23c106b3fad7ba3ec18a',
#   'latitude': 51.056075,
#   'longitude': 3.7090817,
#   'name': 'Coupure rechts 912',
#   'timestamp': '2024-04-18T00:29:30.745000Z'},
#  {'empty_slots': 0,
#   'extra': {'last_updated': 1713387633,
#    'renting': 1,
#    'returning': 1,
#    'uid': '16685'},
#   'free_bikes': 4,
#   'id': '3f41a259ee828855d58f51842c4c1142',
#   'latitude': 51.0547317,
#   'longitude': 3.7506187,
#   'name': 'Engelstraat 77/79',
#   'timestamp': '2024-04-18T00:29:30.974000Z'},
#  {'empty_slots': 3,
#   'extra': {'last_updated': 1713367369,
#    'renting': 1,
#    'returning': 1,
#    'uid': '28567'},
#   'free_bikes': 0,
#   'id': '6910652fda628790ce2c55f352706a9c',
#   'latitude': 51.0449617,
#   'longitude': 3.7410694,
#   'name': 'Tarbotstraat 14',
#   'timestamp': '2024-04-18T00:29:30.560000Z'},
#  {'empty_slots': 1,
#   'extra': {'last_updated': 1713393584,
#    'renting': 1,
#    'returning': 1,
#    'uid': '12144'},
#   'free_bikes': 3,
#   'id': 'f6812b632313589325d1140b64d1b2f4',
#   'latitude': 51.0271622,
#   'longitude': 3.7313799,
#   'name': 'Armand Heinsstraat 61',
#   'timestamp': '2024-04-18T00:29:31.034000Z'},
#  {'empty_slots': 3,
#   'extra': {'last_updated': 1713198930,
#    'renting': 1,
#    'returning': 1,
#    'uid': '13228'},
#   'free_bikes': 0,
#   'id': 'e44ad2d4e378455b8be0c43103bfb7bb',
#   'latitude': 51.0279458,
#   'longitude': 3.7249487,
#   'name': 'De Pintelaan 137',
#   'timestamp': '2024-04-18T00:29:30.360000Z'},
#  {'empty_slots': 7,
#   'extra': {'last_updated': 1713390281,
#    'renting': 1,
#    'returning': 1,
#    'uid': '12434'},
#   'free_bikes': 9,
#   'id': 'b6444db9caf8058bc94fc207ebbea301',
#   'latitude': 51.0491181,
#   'longitude': 3.7034175,
#   'name': 'UGent Campus Dunant',
#   'timestamp': '2024-04-18T00:29:30.992000Z'},
#  {'empty_slots': 3,
#   'extra': {'last_updated': 1713021062,
#    'renting': 1,
#    'returning': 1,
#    'uid': '28756'},
#   'free_bikes': 0,
#   'id': 'adb778577785d1168ab93a67034668b5',
#   'latitude': 51.0481605,
#   'longitude': 3.7226288,
#   'name': 'Rozendaalken',
#   'timestamp': '2024-04-18T00:29:31.389000Z'},
#  {'empty_slots': 2,
#   'extra': {'last_updated': 1713127135,
#    'renting': 1,
#    'returning': 1,
#    'uid': '28764'},
#   'free_bikes': 1,
#   'id': 'bf64b71006b43dd162b7740c6e57a371',
#   'latitude': 51.0302737,
#   'longitude': 3.6890922,
#   'name': 'Amelia Earhartlaan Park Inside',
#   'timestamp': '2024-04-18T00:29:31.142000Z'},
#  {'empty_slots': 3,
#   'extra': {'last_updated': 1713351507,
#    'renting': 1,
#    'returning': 1,
#    'uid': '28815'},
#   'free_bikes': 0,
#   'id': '9ed458708a7e717d92a58ec43375d61e',
#   'latitude': 51.0415554,
#   'longitude': 3.7356781,
#   'name': 'Residence Du Sud',
#   'timestamp': '2024-04-18T00:29:31.203000Z'},
#  {'empty_slots': 1,
#   'extra': {'last_updated': 1712943705,
#    'renting': 1,
#    'returning': 1,
#    'uid': '28816'},
#   'free_bikes': 1,
#   'id': '3ad1c6be872e2c947e5da9e72893787d',
#   'latitude': 51.0279846,
#   'longitude': 3.7565222,
#   'name': 'Jules de Saint-Genoisstraat 112',
#   'timestamp': '2024-04-18T00:29:30.498000Z'},
#  {'empty_slots': 6,
#   'extra': {'last_updated': 1713375195,
#    'renting': 1,
#    'returning': 1,
#    'uid': '12179'},
#   'free_bikes': 10,
#   'id': '6e0bc745f53a2806d9499b8737557d11',
#   'latitude': 51.0492256,
#   'longitude': 3.6875757,
#   'name': 'Skate & Parkour',
#   'timestamp': '2024-04-18T00:29:30.675000Z'},
#  {'empty_slots': 2,
#   'extra': {'last_updated': 1713203860,
#    'renting': 1,
#    'returning': 1,
#    'uid': '28826'},
#   'free_bikes': 1,
#   'id': 'e70ed60da01e0c5b3cfff1978212f92a',
#   'latitude': 51.0486582,
#   'longitude': 3.7207245,
#   'name': 'Frans Tavernierstraat',
#   'timestamp': '2024-04-18T00:29:30.680000Z'},
#  {'empty_slots': 4,
#   'extra': {'last_updated': 1713385729,
#    'renting': 1,
#    'returning': 1,
#    'uid': '12115'},
#   'free_bikes': 0,
#   'id': '62f39a1526ab1e751dde2f508439439f',
#   'latitude': 51.0548227,
#   'longitude': 3.7335079,
#   'name': 'Nieuwbrugkaai 79',
#   'timestamp': '2024-04-18T00:29:31.346000Z'}]

# %% [markdown]
# Put your parsed results into a DataFrame.

# %% [markdown]
# First, to better understand the structure of the dataframe that will be created, I will use a singular entry to confirm the column names of the dataframe

# %%
stations['network']['stations'][5]
# Out:
# {'empty_slots': 3,
#  'extra': {'last_updated': 1713376944,
#   'renting': 1,
#   'returning': 1,
#   'uid': '13162'},
#  'free_bikes': 0,
#  'id': 'dfb4810ce36bce22c088da09bc37132d',
#  'latitude': 51.0655317,
#  'longitude': 3.6993996,
#  'name': 'Groendreef 133',
#  'timestamp': '2024-04-18T00:29:30.368000Z'}

# %%
stations_list = []  #an empty list for stations
for station in stations['network']['stations']: #a for loop to iterate through the json file
   stations_data = {
    'station_id': station['id'],
    'station_name': station['name'],
    'latitude': station['latitude'],
    'longitude': station['longitude'],
    'empty_slots': station['empty_slots'],
    'free_bikes': station['free_bikes'],
    'timestamp': station['timestamp'],
    'station_uid': station['extra']['uid'],
    'renting': station['extra']['renting'],
    'returning': station['extra']['returning'],
    'last_updated': station['extra']['last_updated']
   }
   stations_list.append(stations_data) #appending the data to the empty list

#Dataframe
stations_df = pd.DataFrame(stations_list)   #converting the list to a dataframe

# %%
stations_df.head()
# Out:
#                          station_id           station_name   latitude  \
# 0  fedd9729d9183b05bb4a3bd9da7d7de1            Nieuwland 1  51.060257
# 1  360b8beb20716998aea9c9a9bbe9720f                   IKEA  51.023691
# 2  c41d2c76618e7fa70fb587d1c2f0497d     Opgeëistenlaan 401  51.063068
# 3  0af3043c5906684b3afc97f387c94430  Land van Waaslaan 128  51.058521
# 4  31578db5c5ecc8491f076cf2023ccc7d    Wittemolenstraat 40  51.056576
#
#    longitude  empty_slots  free_bikes                    timestamp  \
# 0   3.729346            2           1  2024-04-18T00:29:30.343000Z
# 1   3.689235            9           3  2024-04-18T00:29:30.349000Z
# 2   3.715993            2           4  2024-04-18T00:29:30.350000Z
# 3   3.747583            0           3  2024-04-18T00:29:30.361000Z
# 4   3.749530            2           1  2024-04-18T00:29:30.365000Z
#
#   station_uid  renting  returning  last_updated
# 0       23997        1          1    1713387373
# 1       23991        1          1    1713358694
# 2       12392        1          1    1713165557
# 3       13169        1          1    1713297425
# 4       13245        1          1    1713385625

# %%
stations_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 406 entries, 0 to 405
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   station_id    406 non-null    object
#  1   station_name  406 non-null    object
#  2   latitude      406 non-null    float64
#  3   longitude     406 non-null    float64
#  4   empty_slots   406 non-null    int64
#  5   free_bikes    406 non-null    int64
#  6   timestamp     406 non-null    object
#  7   station_uid   406 non-null    object
#  8   renting       406 non-null    int64
#  9   returning     406 non-null    int64
#  10  last_updated  406 non-null    int64
# dtypes: float64(2), int64(5), object(4)
# memory usage: 35.0+ KB

# %%
stations_df['timestamp'] = pd.to_datetime(stations_df['timestamp'], format='ISO8601') #converting the timestamp to a datetime object
stations_df['timestamp']
# Out:
# 0     2024-04-18 00:29:30.343000+00:00
# 1     2024-04-18 00:29:30.349000+00:00
# 2     2024-04-18 00:29:30.350000+00:00
# 3     2024-04-18 00:29:30.361000+00:00
# 4     2024-04-18 00:29:30.365000+00:00
#                     ...
# 401   2024-04-18 00:29:31.203000+00:00
# 402   2024-04-18 00:29:30.498000+00:00
# 403   2024-04-18 00:29:30.675000+00:00
# 404   2024-04-18 00:29:30.680000+00:00
# 405   2024-04-18 00:29:31.346000+00:00
# Name: timestamp, Length: 406, dtype: datetime64[ns, UTC]

# %%
stations_df.describe()
# Out:
#          latitude   longitude  empty_slots  free_bikes  renting  returning  \
# count  406.000000  406.000000   406.000000  406.000000    406.0      406.0
# mean    51.049707    3.722364     4.280788    1.312808      1.0        1.0
# std      0.012877    0.017117     3.618195    1.911159      0.0        0.0
# min     50.998190    3.676415     0.000000    0.000000      1.0        1.0
# 25%     51.041699    3.710837     2.000000    0.000000      1.0        1.0
# 50%     51.050625    3.723110     3.000000    1.000000      1.0        1.0
# 75%     51.057350    3.732759     6.000000    2.000000      1.0        1.0
# max     51.099393    3.767021    24.000000   14.000000      1.0        1.0
#
#        last_updated
# count  4.060000e+02
# mean   1.713262e+09
# std    3.836419e+05
# min    1.708365e+09
# 25%    1.713272e+09
# 50%    1.713365e+09
# 75%    1.713380e+09
# max    1.713400e+09

# %% [markdown]
# We can see that renting and returning is basically always a 1 as the standard deviation is 0. So renting and returning are redundant variables here.
# The format of last updated is also strange. The timesetap is already telling us when the station was last updated on the system, therefore I am not sure what that variable is for.

# %%
stations_df['free_bikes'].value_counts()
# Out:
# free_bikes
# 0     169
# 1     114
# 2      55
# 3      35
# 4      13
# 5       8
# 9       3
# 6       3
# 11      2
# 8       1
# 13      1
# 14      1
# 10      1
# Name: count, dtype: int64

# %%
stations_df['empty_slots'].value_counts()
# Out:
# empty_slots
# 3     122
# 2      71
# 6      47
# 1      35
# 5      25
# 0      22
# 4      20
# 10     11
# 8       9
# 12      9
# 9       8
# 11      7
# 7       7
# 16      3
# 13      3
# 21      2
# 24      1
# 14      1
# 18      1
# 15      1
# 20      1
# Name: count, dtype: int64

# %%
#Check if all stations IDs are unique
stations_df['station_id'].nunique()
# Out:
# 406

# %%
stations_df.to_csv('gent_bike_stations.csv', index=False) #saving the dataframe to a csv file
